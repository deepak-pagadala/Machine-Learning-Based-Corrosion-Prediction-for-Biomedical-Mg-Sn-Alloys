# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows", None)

# %%
df_mg_1sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_1sn_24h_bode.xlsx') 
df_mg_1sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_1sn_48h_bode.xlsx')
df_mg_1sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_1sn_72h_bode.xlsx')
df_mg_5sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_5sn_24h_bode.xlsx') 
df_mg_5sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_5sn_48h_bode.xlsx')
df_mg_5sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_5sn_72h_bode.xlsx')  
df_mg_10sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_10sn_24h_bode.xlsx') 
df_mg_10sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_10sn_48h_bode.xlsx')
df_mg_10sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/bode/mg_10sn_72h_bode.xlsx')

# %%
df_mg_1sn = df_mg_1sn.iloc[1:]
df_mg_1sn_48h = df_mg_1sn_48h.iloc[1:]
df_mg_1sn_72h = df_mg_1sn_72h.iloc[1:]
df_mg_5sn = df_mg_5sn.iloc[1:]
df_mg_5sn_48h = df_mg_5sn_48h.iloc[1:]
df_mg_5sn_72h = df_mg_5sn_72h.iloc[1:]
df_mg_10sn = df_mg_10sn.iloc[1:]
df_mg_10sn_48h = df_mg_10sn_48h.iloc[1:]
df_mg_10sn_72h = df_mg_10sn_72h.iloc[1:]

# %%
df_mg_1sn = df_mg_1sn.rename(columns={"ab": "Img"})
df_mg_5sn = df_mg_5sn.rename(columns={"ab": "Img"})
df_mg_10sn = df_mg_10sn.rename(columns={"ab": "Img"})
df_mg_1sn_48h = df_mg_1sn_48h.rename(columns={"ab": "Img"})
df_mg_1sn_72h = df_mg_1sn_72h.rename(columns={"ab": "Img"})
df_mg_5sn_48h = df_mg_5sn_48h.rename(columns={"ab": "Img"})
df_mg_5sn_72h = df_mg_5sn_72h.rename(columns={"ab": "Img"})
df_mg_10sn_48h = df_mg_10sn_48h.rename(columns={"ab": "Img"})
df_mg_10sn_72h = df_mg_10sn_72h.rename(columns={"ab": "Img"})

# %%
plt.plot(np.log(df_mg_1sn["Img"].values),df_mg_1sn["cd"].values,'r',label = 'mg_1sn 24hr')
plt.plot(np.log(df_mg_1sn_48h["Img"].values),df_mg_1sn_48h["cd"].values,'b',label = 'mg_1sn 48hr')
plt.plot(np.log(df_mg_1sn_72h["Img"].values),df_mg_1sn_72h["cd"].values,'g',label = 'mg_1sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
plt.plot(np.log(df_mg_5sn["Img"].values),df_mg_5sn["cd"].values,'r',label = 'mg_5sn 24hr')
plt.plot(np.log(df_mg_5sn_48h["Img"].values),df_mg_5sn_48h["cd"].values,'b',label = 'mg_5sn 48hr')
plt.plot(np.log(df_mg_5sn_72h["Img"].values),df_mg_5sn_72h["cd"].values,'g',label = 'mg_5sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
plt.plot(np.log(df_mg_10sn["Img"].values),df_mg_10sn["cd"].values,'r',label = 'mg_10sn 24hr')
plt.plot(np.log(df_mg_10sn_48h["Img"].values),df_mg_10sn_48h["cd"].values,'b',label = 'mg_10sn 48hr')
plt.plot(np.log(df_mg_10sn_72h["Img"].values),df_mg_10sn_72h["cd"].values,'g',label = 'mg_1sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
df_mg_1sn["Img"] = np.log(df_mg_1sn["Img"].values)
df_mg_1sn_48h["Img"] = np.log(df_mg_1sn_48h["Img"].values)
df_mg_1sn_72h["Img"] = np.log(df_mg_1sn_72h["Img"].values)
df_mg_5sn["Img"] = np.log(df_mg_5sn["Img"].values)
df_mg_5sn_48h["Img"] = np.log(df_mg_5sn_48h["Img"].values)
df_mg_5sn_72h["Img"] = np.log(df_mg_5sn_72h["Img"].values)
df_mg_10sn["Img"] = np.log(df_mg_10sn["Img"].values)
df_mg_10sn_48h["Img"] = np.log(df_mg_10sn_48h["Img"].values)
df_mg_10sn_72h["Img"] = np.log(df_mg_10sn_72h["Img"].values)

# %%
result_df = pd.concat([df_mg_5sn,df_mg_5sn_48h,df_mg_5sn_72h])

# %%
result_df["cd"] = result_df["cd"].values.astype('float64')

# %%
result_df = result_df.drop(['XY'], axis=1)

# %%
x, y = result_df.drop(['cd'], axis=1), result_df['cd'].values.astype('float64')

# %% [markdown]
# xg boost

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error, mean_absolute_error
from math import sqrt
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=42)
xgb_model = xgb.XGBRegressor(random_state = 0)
xgb_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,xgb_model.predict(x_test)))
print(mean_absolute_error(y_test,xgb_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,xgb_model.predict(x_test))))
# Out:
# [06:05:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9619945119794132
# 1.9176023040135703
# 2.741274242108371

# %%
xgb_model.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
'''
plt.plot(df_mg_5sn['Img'].values,df_mg_5sn['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn['Img'].values,xgb_model.predict(df_mg_5sn.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')

plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()'''
# Out:
# "\nplt.plot(df_mg_5sn['Img'].values,df_mg_5sn['cd'].values,'r',label = 'Experimental')\nplt.plot(df_mg_5sn['Img'].values,xgb_model.predict(df_mg_5sn.drop(['XY','cd'],axis=1)),'b',label='Predicted')\nplt.legend()\n#plt.title('Base')\n\nplt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')\nplt.show()"

# %%
'''
plt.plot(df_mg_5sn_48h['Img'].values,df_mg_5sn_48h['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn_48h['Img'].values,xgb_model.predict(df_mg_5sn_48h.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()'''
# Out:
# "\nplt.plot(df_mg_5sn_48h['Img'].values,df_mg_5sn_48h['cd'].values,'r',label = 'Experimental')\nplt.plot(df_mg_5sn_48h['Img'].values,xgb_model.predict(df_mg_5sn_48h.drop(['XY','cd'],axis=1)),'b',label='Predicted')\nplt.legend()\n#plt.title('Base')\nplt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')\nplt.show()"

# %%
'''
plt.plot(df_mg_5sn_72h['Img'].values,df_mg_5sn_72h['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn_72h['Img'].values,xgb_model.predict(df_mg_5sn_72h.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()'''
# Out:
# "\nplt.plot(df_mg_5sn_72h['Img'].values,df_mg_5sn_72h['cd'].values,'r',label = 'Experimental')\nplt.plot(df_mg_5sn_72h['Img'].values,xgb_model.predict(df_mg_5sn_72h.drop(['XY','cd'],axis=1)),'b',label='Predicted')\nplt.legend()\n#plt.title('Base')\nplt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')\nplt.show()"

# %%
from xgboost import plot_importance
#reduction in mse
plot_importance(xgb_model)
plt.show()

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 348 kB 35.3 MB/s
# ...
#      |████████████████████████████████| 209 kB 56.9 MB/s
# ...
#      |████████████████████████████████| 81 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 49 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 112 kB 80.6 MB/s
# ...
#      |████████████████████████████████| 147 kB 83.7 MB/s
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=429293f523c93e14d3f59b817fba5044e22677dce6503dcdd891a09178dd1d34
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# ...

# %%
import optuna

# %%
def xgb_objective(trial):
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.15)
    param = {
        'silent': 1,
        'random_state': 0,
        'objective': 'reg:linear',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-4, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-4, 1.0),
        'n_estimators': trial.suggest_int('n_estimators',10,100),
        'learning_rate': trial.suggest_loguniform('learning_rste', 1e-4, 0.1),
        'max_depth':trial.suggest_int('max_depth',3,6)
    }
    bst = xgb.XGBRegressor(**param)
    bst.fit(train_x,train_y)
    return sqrt(mean_squared_error(test_y,bst.predict(test_x)))

# %%
SEED = 42

np.random.seed(SEED)
xgb_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(seed=SEED),pruner=optuna.pruners.SuccessiveHalvingPruner())
xgb_study.optimize(xgb_objective, n_trials=100)
# Out:
# [I 2022-09-21 06:05:31,484] A new study created in memory with name: no-name-6beb9c1e-6a68-49e7-b43b-b1aa02c73bc2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if __name__ == '__main__':
# ...

# %%
from typing import Callable
from typing import Optional

import numpy as np

#from optuna._experimental import experimental
from optuna.logging import get_logger
from optuna.study import Study
from optuna.study import StudyDirection
from optuna.trial import FrozenTrial
from optuna.trial import TrialState
from optuna.visualization._utils import _check_plot_args
from optuna.visualization.matplotlib._matplotlib_imports import _imports


if _imports.is_successful():
    from optuna.visualization.matplotlib._matplotlib_imports import Axes
    from optuna.visualization.matplotlib._matplotlib_imports import plt

_logger = get_logger(__name__)

# %%
def optimization_history(
    study: Study,
    *,
    target: Optional[Callable[[FrozenTrial], float]] = None,
    target_name: str = "Objective Value",
) -> "Axes":
    """Plot optimization history of all trials in a study with Matplotlib.
    .. seealso::
        Please refer to :func:`optuna.visualization.plot_optimization_history` for an example.
    Example:
        The following code snippet shows how to plot optimization history.
        .. plot::
            import optuna
            def objective(trial):
                x = trial.suggest_float("x", -100, 100)
                y = trial.suggest_categorical("y", [-1, 0, 1])
                return x ** 2 + y
            sampler = optuna.samplers.TPESampler(seed=10)
            study = optuna.create_study(sampler=sampler)
            study.optimize(objective, n_trials=10)
            optuna.visualization.matplotlib.plot_optimization_history(study)
    Args:
        study:
            A :class:`~optuna.study.Study` object whose trials are plotted for their target values.
        target:
            A function to specify the value to display. If it is :obj:`None` and ``study`` is being
            used for single-objective optimization, the objective values are plotted.
            .. note::
                Specify this argument if ``study`` is being used for multi-objective optimization.
        target_name:
            Target's name to display on the axis label and the legend.
    Returns:
        A :class:`matplotlib.axes.Axes` object.
    Raises:
        :exc:`ValueError`:
            If ``target`` is :obj:`None` and ``study`` is being used for multi-objective
            optimization.
    """

    _imports.check()
    _check_plot_args(study, target, target_name)
    get_optimization_history_plot(study, target, target_name)
    return 0


def get_optimization_history_plot(
    study: Study,
    target: Optional[Callable[[FrozenTrial], float]],
    target_name: str,
) -> "Axes":

    # Set up the graph style.
    fig = plt.figure()
    plt.title("Optimization History Plot")
    plt.xlabel("#Trials")
    plt.ylabel(target_name)
    
    # Prepare data for plotting.
    trials = [t for t in study.trials if t.state == TrialState.COMPLETE]

    if len(trials) == 0:
        _logger.warning("Study instance does not contain trials.")
        return 0

    # Draw a scatter plot and a line plot.
    if target is None:
        if study.direction == StudyDirection.MINIMIZE:
            best_values = np.minimum.accumulate([t.value for t in trials])
        else:
            best_values = np.maximum.accumulate([t.value for t in trials])
        plt.scatter(
            x=[t.number for t in trials],
            y=[t.value for t in trials],
            color='blue',
            alpha=1,
            label=target_name,
        )
        plt.plot(
            [t.number for t in trials],
            best_values,
            marker="o",
            color='red',
            alpha=0.5,
            label="Best Value",
        )

        plt.legend()
    else:
        plt.scatter(
            x=[t.number for t in trials],
            y=[target(t) for t in trials],
            color='red',
            alpha=1,
            label=target_name,
        )
    plt.savefig('bode_opt_his.png',dpi = 1200,bbox_inches='tight')
    plt.show()

# %%
optimization_history(xgb_study)
# Out:
# 0

# %%
best_params=xgb_study.best_params 
best_params
# Out:
# {'booster': 'dart',
#  'reg_lambda': 0.5876546246628207,
#  'reg_alpha': 0.15297296933723034,
#  'n_estimators': 56,
#  'learning_rste': 0.059920619802728205,
#  'max_depth': 5}

# %%
final_model = xgb.XGBRegressor(**best_params)
final_model.fit(x_train,y_train)
# Out:
# [06:05:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(booster='dart', learning_rste=0.059920619802728205, max_depth=5,
#              n_estimators=56, reg_alpha=0.15297296933723034,
#              reg_lambda=0.5876546246628207)

# %%
print(r2_score(y_test,final_model.predict(x_test)))
print(mean_absolute_error(y_test,final_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,final_model.predict(x_test))))
# Out:
# 0.9561989666418927
# 2.0088762668609617
# 2.942872907349556

# %%
def _label_barh(bars, text_format, **kwargs):
    """
    Attach a text label to each bar displaying its y value
    Note: label always outside. otherwise it's too hard to control as numbers can be very long
    """
    max_x_value = 1.0
    distance = max_x_value * 0.0025

    for bar in bars:
        text = text_format.format(bar.get_width())

        text_x = bar.get_width() + distance
        text_y = bar.get_y() + bar.get_height() / 2

        plt.text(text_x, text_y, text, va='center', **kwargs)

def label_bars(bars, text_format, **kwargs):
    """
    Attaches a label on every bar of a regular or horizontal bar chart
    """
    ys = [bar.get_y() for bar in bars]
    y_is_constant = all(y == ys[0] for y in ys)  # -> regular bar chart, since all all bars start on the same y level (0)

    if y_is_constant:
        _label_bar(bars, text_format, **kwargs)
    else:
        _label_barh(bars, text_format, **kwargs)

# %%
plt.plot(df_mg_5sn['Img'].values,df_mg_5sn['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn['Img'].values,final_model.predict(df_mg_5sn.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')

plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_5sn_48h['Img'].values,df_mg_5sn_48h['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn_48h['Img'].values,final_model.predict(df_mg_5sn_48h.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn_72h['Img'].values,df_mg_10sn_72h['cd'].values,'r',label = 'Experimental')
plt.plot(df_mg_10sn_72h['Img'].values,final_model.predict(df_mg_10sn_72h.drop(['XY','cd'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()
