# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly

# %%
pd.set_option("display.max_rows", None)

# %%
df_mg_1sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_1sn_24h_nyquist.xlsx') 
df_mg_1sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_1sn_48h_nyquist.xlsx')
df_mg_1sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_1sn_72h_nyquist.xlsx')
df_mg_5sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_5sn_24h_nyquist.xlsx') 
df_mg_5sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_5sn_48h_nyquist.xlsx')
df_mg_5sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_5sn_72h_nyquist.xlsx')  
df_mg_10sn = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_10sn_24h_nyquist.xlsx') 
df_mg_10sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_10sn_48h_nyquist.xlsx')
df_mg_10sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/nyquist/mg_10sn_72h_nyquist.xlsx')

# %%
df_mg_1sn = df_mg_1sn.iloc[1:]
df_mg_1sn_48h = df_mg_1sn_48h.iloc[1:]
df_mg_1sn_72h = df_mg_1sn_72h.iloc[1:]
df_mg_5sn = df_mg_5sn.iloc[1:]
df_mg_5sn_48h = df_mg_5sn_48h.iloc[1:]
df_mg_5sn_72h = df_mg_5sn_72h.iloc[1:]
df_mg_10sn = df_mg_10sn.iloc[1:]
df_mg_10sn_48h = df_mg_10sn_48h.iloc[1:]
df_mg_10sn_72h = df_mg_10sn_72h.iloc[1:]

# %%
df_mg_1sn = df_mg_1sn.rename(columns={"ab": "Img"})
df_mg_5sn = df_mg_5sn.rename(columns={"sp": "Img"})
df_mg_10sn = df_mg_10sn.rename(columns={"htsp": "Img"})
df_mg_1sn_48h = df_mg_1sn_48h.rename(columns={"ab": "Img"})
df_mg_1sn_72h = df_mg_1sn_72h.rename(columns={"ab": "Img"})
df_mg_5sn_48h = df_mg_5sn_48h.rename(columns={"ab": "Img"})
df_mg_5sn_72h = df_mg_5sn_72h.rename(columns={"ab": "Img"})
df_mg_10sn_48h = df_mg_10sn_48h.rename(columns={"ab": "Img"})
df_mg_10sn_72h = df_mg_10sn_72h.rename(columns={"ab": "Img"})

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'mg_1sn 24hr')
#plt.plot(df_mg_5sn["XY"].values,df_mg_5sn["Img"].values,'b',label = 'mg_5sn 24hr')
#plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'g',label = 'mg_10sn 24hr')
plt.plot(df_mg_1sn_48h["XY"].values,df_mg_1sn_48h["Img"].values,'b',label = 'mg_1sn 48hr')
plt.plot(df_mg_1sn_72h["XY"].values,df_mg_1sn_72h["Img"].values,'g',label = 'mg_1sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
plt.plot(df_mg_5sn["XY"].values,df_mg_5sn["Img"].values,'r',label = 'mg_5sn 24hr')
#plt.plot(df_mg_5sn["XY"].values,df_mg_5sn["Img"].values,'b',label = 'mg_5sn 24hr')
#plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'g',label = 'mg_10sn 24hr')
plt.plot(df_mg_5sn_48h["XY"].values,df_mg_5sn_48h["Img"].values,'b',label = 'mg_5sn 48hr')
plt.plot(df_mg_5sn_72h["XY"].values,df_mg_5sn_72h["Img"].values,'g',label = 'mg_5sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'r',label = 'mg_5sn 24hr')
#plt.plot(df_mg_5sn["XY"].values,df_mg_5sn["Img"].values,'b',label = 'mg_5sn 24hr')
#plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'g',label = 'mg_10sn 24hr')
plt.plot(df_mg_10sn_48h["XY"].values,df_mg_10sn_48h["Img"].values,'b',label = 'mg_5sn 48hr')
plt.plot(df_mg_10sn_72h["XY"].values,df_mg_10sn_72h["Img"].values,'g',label = 'mg_5sn 72hr')
plt.legend()
plt.title(' Nyquist Plot ')
'''plt.xlabel('Z_Real')
plt.ylabel('Z_Img')'''

plt.show()

# %%
result_df =pd.concat([df_mg_5sn,df_mg_5sn_48h,df_mg_5sn_72h],axis=0)
result_df = result_df.sort_values(["XY"], ignore_index=True)

# %%
result_df.shape
# Out:
# (300, 2)

# %%
print_df = result_df
print_df = print_df.rename(columns={'XY':'Z_real','Img':'Z_img'})

# %%
print_df
# Out:
#      Z_real     Z_img
# 0     58.20    3.5080
# 1     58.26    2.8300
# 2     58.33    3.7060
# 3     58.43    3.6460
# 4     58.84    4.3310
# 5     58.96    5.2520
# 6     58.99    4.3010
# 7     59.02    4.0990
# 8     59.11    2.4820
# 9     59.17    3.9560
# 10    59.37    4.1890
# 11    59.59    4.4130
# 12    59.71    4.8130
# 13    59.82    4.6930
# 14    59.85    5.2900
# 15    60.06    4.9660
# 16    60.13    5.6200
# 17    60.19    6.2170
# 18    60.29    5.2430
# 19    60.40    5.9480
# 20    60.48    6.2430
# 21    60.54    5.5750
# 22    60.69    6.6360
# 23    60.83    5.9900
# 24    60.85    6.7520
# 25    61.02    7.0230
# 26    61.10    7.3330
# 27    61.11    6.3340
# 28    61.32    7.3860
# 29    61.44    6.7940
# 30    61.68    7.8390
# 31    61.76    7.2420
# 32    62.07    7.8860
# 33    62.09    8.3610
# 34    62.09    8.2870
# 35    62.46    8.4390
# 36    62.47    8.8700
# 37    62.50    7.0120
# 38    62.50    8.7870
# 39    62.84    9.0000
# ...

# %%
x, y = result_df.drop(['Img'], axis=1), result_df['Img'].values.astype('float64')

# %% [markdown]
# xgboost

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=6)
xgb_model = xgb.XGBRegressor(random_state = 1)
xgb_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,xgb_model.predict(x_test)))
print(mean_absolute_error(y_test,xgb_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,xgb_model.predict(x_test))))
# Out:
# [06:37:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.5322441718106196
# 25.899202682367957
# 50.97193251920607

# %%
xgb_model.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 1,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn["XY"].values,xgb_model.predict(df_mg_1sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_48h["XY"].values,df_mg_1sn_48h["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn_48h["XY"].values,xgb_model.predict(df_mg_1sn_48h.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('ht')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_xgb_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()
plt.show()

# %%
plt.plot(df_mg_1sn_72h["XY"].values,df_mg_1sn_72h["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn_72h["XY"].values,xgb_model.predict(df_mg_1sn_72h.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('sp')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_xgb_sp.png',dpi = 1200,bbox_inches='tight')
plt.show()
plt.show()

# %% [markdown]
# Fitting a Support Vector Regression

# %%
from sklearn import svm
svr_model = svm.SVR(kernel='linear', epsilon = 0.1)
svr_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,svr_model.predict(x_test)))
print(mean_absolute_error(y_test,svr_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,svr_model.predict(x_test))))
# Out:
# 0.05370053021229171
# 36.742702107610945
# 55.365129853970586

# %%
svr_model.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn["XY"].values,svr_model.predict(df_mg_1sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_svm_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()
#plt.title('base')
plt.show()

# %%
plt.plot(df_mg_1sn_48h["XY"].values,df_mg_1sn_48h["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn_48h["XY"].values,svr_model.predict(df_mg_1sn_48h.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('HT')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_svm_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_72h["XY"].values,df_mg_1sn_72h["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn_72h["XY"].values,svr_model.predict(df_mg_1sn_72h.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('SP')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_svm_sp.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# Fitting a Decision Tree

# %%
from sklearn import tree
dt_model = tree.DecisionTreeRegressor(max_depth = 6)
dt_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,dt_model.predict(x_test)))
print(mean_absolute_error(y_test,dt_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,dt_model.predict(x_test))))
# Out:
# 0.6902937735131947
# 14.175841187930965
# 31.67356827759894

# %%
dt_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 6,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn["XY"].values,dt_model.predict(df_mg_1sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('base')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_dt_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_48h["XY"].values,df_mg_1sn_48h["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn_48h["XY"].values,dt_model.predict(df_mg_1sn_48h.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('HT')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_dt_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_10sn["XY"].values,dt_model.predict(df_mg_10sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('SP')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_dt_sp.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# Fitting a Polynomial Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

linear_model = LinearRegression()
degree=2
poly_model =make_pipeline(PolynomialFeatures(degree),LinearRegression())

poly_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,poly_model.predict(x_test)))
print(mean_absolute_error(y_test,poly_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,poly_model.predict(x_test))))
# Out:
# 0.33067941341330553
# 36.586087917470785
# 46.56280297507056

# %%
poly_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('polynomialfeatures', PolynomialFeatures()),
#   ('linearregression', LinearRegression())],
#  'verbose': False,
#  'polynomialfeatures': PolynomialFeatures(),
#  'linearregression': LinearRegression(),
#  'polynomialfeatures__degree': 2,
#  'polynomialfeatures__include_bias': True,
#  'polynomialfeatures__interaction_only': False,
#  'polynomialfeatures__order': 'C',
#  'linearregression__copy_X': True,
#  'linearregression__fit_intercept': True,
#  'linearregression__n_jobs': None,
#  'linearregression__normalize': 'deprecated',
#  'linearregression__positive': False}

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_1sn["XY"].values,poly_model.predict(df_mg_1sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('HT')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_poly_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_5sn["XY"].values,df_mg_5sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_5sn["XY"].values,poly_model.predict(df_mg_5sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('HT')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_poly_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn["XY"].values,df_mg_10sn["Img"].values,'r',label = 'Experimental')
plt.plot(df_mg_10sn["XY"].values,poly_model.predict(df_mg_10sn.drop(['Img'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('HT')
plt.xlabel('Z_Real    (in ohms)')
plt.ylabel('Z_Img    (in ohms)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/nyquist/nyquist_poly_sp.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# XGBoost Feature Importance

# %%
from xgboost import plot_importance
#reduction in mse
plot_importance(xgb_model)
plt.show()

# %% [markdown]
# Optuna For Hyperparameter Optimisation

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 348 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 81 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 209 kB 18.9 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 49 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 147 kB 46.8 MB/s
# ...
#      |████████████████████████████████| 112 kB 54.5 MB/s
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=060f5c433cfd94e2d77843277a2d9a757418b4c0d8e9457608cc3190a2a7421f
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# ...

# %%
import optuna

# %%
def xgb_objective(trial):
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.12)
    param = {
        'silent': 1,
        'random_state': 2,
        'objective': 'reg:linear',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-4, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-4, 1.0),
        'n_estimators': trial.suggest_int('n_estimators',10,100),
        'learning_rate': trial.suggest_loguniform('learning_rste', 1e-4, 0.1),
        'max_depth':trial.suggest_int('max_depth',3,6)
    }
    bst = xgb.XGBRegressor(**param)
    bst.fit(train_x,train_y)
    return sqrt(mean_squared_error(test_y,bst.predict(test_x)))

# %%
SEED = 42

np.random.seed(SEED)

xgb_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(seed=SEED),pruner=optuna.pruners.SuccessiveHalvingPruner())
xgb_study.optimize(xgb_objective, n_trials=100)
# Out:
# [I 2022-09-21 06:37:35,744] A new study created in memory with name: no-name-af9c5e52-7d44-4ad7-8cb2-735e7da47376
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if __name__ == '__main__':
# ...

# %%
from typing import Callable
from typing import Optional

import numpy as np

#from optuna._experimental import experimental
from optuna.logging import get_logger
from optuna.study import Study
from optuna.study import StudyDirection
from optuna.trial import FrozenTrial
from optuna.trial import TrialState
from optuna.visualization._utils import _check_plot_args
from optuna.visualization.matplotlib._matplotlib_imports import _imports


if _imports.is_successful():
    from optuna.visualization.matplotlib._matplotlib_imports import Axes
    from optuna.visualization.matplotlib._matplotlib_imports import plt

_logger = get_logger(__name__)

# %%
def optimization_history(
    study: Study,
    *,
    target: Optional[Callable[[FrozenTrial], float]] = None,
    target_name: str = "Objective Value",
) -> "Axes":
    """Plot optimization history of all trials in a study with Matplotlib.
    .. seealso::
        Please refer to :func:`optuna.visualization.plot_optimization_history` for an example.
    Example:
        The following code snippet shows how to plot optimization history.
        .. plot::
            import optuna
            def objective(trial):
                x = trial.suggest_float("x", -100, 100)
                y = trial.suggest_categorical("y", [-1, 0, 1])
                return x ** 2 + y
            sampler = optuna.samplers.TPESampler(seed=10)
            study = optuna.create_study(sampler=sampler)
            study.optimize(objective, n_trials=10)
            optuna.visualization.matplotlib.plot_optimization_history(study)
    Args:
        study:
            A :class:`~optuna.study.Study` object whose trials are plotted for their target values.
        target:
            A function to specify the value to display. If it is :obj:`None` and ``study`` is being
            used for single-objective optimization, the objective values are plotted.
            .. note::
                Specify this argument if ``study`` is being used for multi-objective optimization.
        target_name:
            Target's name to display on the axis label and the legend.
    Returns:
        A :class:`matplotlib.axes.Axes` object.
    Raises:
        :exc:`ValueError`:
            If ``target`` is :obj:`None` and ``study`` is being used for multi-objective
            optimization.
    """

    _imports.check()
    _check_plot_args(study, target, target_name)
    get_optimization_history_plot(study, target, target_name)
    return 0


def get_optimization_history_plot(
    study: Study,
    target: Optional[Callable[[FrozenTrial], float]],
    target_name: str,
) -> "Axes":

    # Set up the graph style.
    fig = plt.figure()
    plt.title("Optimization History Plot")
    plt.xlabel("#Trials")
    plt.ylabel(target_name)
    
    # Prepare data for plotting.
    trials = [t for t in study.trials if t.state == TrialState.COMPLETE]

    if len(trials) == 0:
        _logger.warning("Study instance does not contain trials.")
        return 0

    # Draw a scatter plot and a line plot.
    if target is None:
        if study.direction == StudyDirection.MINIMIZE:
            best_values = np.minimum.accumulate([t.value for t in trials])
        else:
            best_values = np.maximum.accumulate([t.value for t in trials])
        plt.scatter(
            x=[t.number for t in trials],
            y=[t.value for t in trials],
            color='blue',
            alpha=1,
            label=target_name,
        )
        plt.plot(
            [t.number for t in trials],
            best_values,
            marker="o",
            color='red',
            alpha=0.5,
            label="Best Value",
        )

        plt.legend()
    else:
        plt.scatter(
            x=[t.number for t in trials],
            y=[target(t) for t in trials],
            color='red',
            alpha=1,
            label=target_name,
        )
    plt.savefig('nyquist_opt_his.png',dpi = 1200,bbox_inches='tight')
    plt.show()

# %%
optimization_history(xgb_study)
# Out:
# 0

# %%
xgb_study.trials_dataframe()
# Out:
#     number       value             datetime_start          datetime_complete  \
# 0        0  104.883579 2022-09-21 06:37:35.748991 2022-09-21 06:37:35.764910
# 1        1  121.539522 2022-09-21 06:37:35.767632 2022-09-21 06:37:35.779621
# 2        2  118.882653 2022-09-21 06:37:35.781526 2022-09-21 06:37:35.794842
# 3        3   90.642133 2022-09-21 06:37:35.796594 2022-09-21 06:37:35.809509
# 4        4   89.455379 2022-09-21 06:37:35.811349 2022-09-21 06:37:35.827279
# 5        5   91.911068 2022-09-21 06:37:35.829378 2022-09-21 06:37:35.845567
# 6        6   64.197865 2022-09-21 06:37:35.847173 2022-09-21 06:37:35.911548
# 7        7   78.624645 2022-09-21 06:37:35.913721 2022-09-21 06:37:35.926883
# 8        8   77.388783 2022-09-21 06:37:35.928863 2022-09-21 06:37:35.953384
# 9        9   90.869895 2022-09-21 06:37:35.956201 2022-09-21 06:37:35.968885
# 10      10   56.661748 2022-09-21 06:37:35.971046 2022-09-21 06:37:36.023117
# ...

# %%
best_params=xgb_study.best_params 
best_params
# Out:
# {'booster': 'gbtree',
#  'reg_lambda': 0.009777277256293305,
#  'reg_alpha': 0.14624084207602833,
#  'n_estimators': 26,
#  'learning_rste': 0.06601101394903071,
#  'max_depth': 6}

# %%
final_model = xgb.XGBRegressor(**best_params)
final_model.fit(x_train,y_train)
# Out:
# [06:37:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(learning_rste=0.06601101394903071, max_depth=6, n_estimators=26,
#              reg_alpha=0.14624084207602833, reg_lambda=0.009777277256293305)

# %%
print(r2_score(y_test,final_model.predict(x_test)))
print(mean_absolute_error(y_test,final_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,final_model.predict(x_test))))
# Out:
# 0.5503870180763032
# 24.525144797431096
# 49.97363229255722

# %%
final_model.get_booster().get_score(importance_type='gain')
# Out:
# {'XY': 6797.559174354412}

# %%
gain_unnorm = np.array([6797.559174354412])

# %%
gain = gain_unnorm/np.sum(gain_unnorm)

# %%
gain
# Out:
# array([1.])

# %%
columns = ['Z(Real)' ,'inclination','T']

# %%
def _label_barh(bars, text_format, **kwargs):
    """
    Attach a text label to each bar displaying its y value
    Note: label always outside. otherwise it's too hard to control as numbers can be very long
    """
    max_x_value = 1.0
    distance = max_x_value * 0.0025

    for bar in bars:
        text = text_format.format(bar.get_width())

        text_x = bar.get_width() + distance
        text_y = bar.get_y() + bar.get_height() / 2

        plt.text(text_x, text_y, text, va='center', **kwargs)

def label_bars(bars, text_format, **kwargs):
    """
    Attaches a label on every bar of a regular or horizontal bar chart
    """
    ys = [bar.get_y() for bar in bars]
    y_is_constant = all(y == ys[0] for y in ys)  # -> regular bar chart, since all all bars start on the same y level (0)

    if y_is_constant:
        _label_bar(bars, text_format, **kwargs)
    else:
        _label_barh(bars, text_format, **kwargs)

# %%
horizontal_bars = plt.barh(columns, gain, height= 0.5, align="center")
plt.xlim(0,1.0)
plt.ylabel('Features')
plt.xlabel('Importance')
value_format = "{:.4}"  # displaying values as percentage with one fractional digit
label_bars(horizontal_bars, value_format)

# %%
plt.plot(df_mg_1sn["XY"].values,df_mg_1sn["Img"].values,'r',label = 'Experimental 24h')
plt.plot(df_mg_1sn["XY"].values,final_model.predict(df_mg_1sn.drop(['Img'],axis=1)),'b',label='Predicted 24h')

plt.legend()
#plt.title('Base')

plt.savefig('nyquist_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_48h["XY"].values,df_mg_1sn_48h["Img"].values,'r',label = 'Experimental 48h')
plt.plot(df_mg_1sn_48h["XY"].values,final_model.predict(df_mg_1sn_48h.drop(['Img'],axis=1)),'b',label='Predicted 48h')
plt.legend()
#plt.title('Base')

plt.savefig('nyquist_xgb_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_72h["XY"].values,df_mg_1sn_72h["Img"].values,'r',label = 'Experimental 72h')
plt.plot(df_mg_1sn_72h["XY"].values,final_model.predict(df_mg_1sn_72h.drop(['Img'],axis=1)),'b',label='Predicted 72h')
plt.legend()
#plt.title('Base')

plt.savefig('nyquist_xgb_sp.png',dpi = 1200,bbox_inches='tight')
plt.show()
