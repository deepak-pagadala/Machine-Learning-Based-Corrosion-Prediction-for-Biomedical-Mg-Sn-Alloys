# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_rows", None)

# %%
df_mg_1sn_24h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_1sn_24h_pd.xlsx') 
df_mg_5sn_24h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_5sn_24h_pd.xlsx') 
df_mg_10sn_24h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_10sn_24h_pd.xlsx') 
df_mg_1sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_1sn_48h_pd.xlsx') 
df_mg_5sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_5sn_48h_pd.xlsx') 
df_mg_10sn_48h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_10sn_48h_pd.xlsx') 
df_mg_1sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_1sn_72h_pd.xlsx') 
df_mg_5sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_5sn_72h_pd.xlsx') 
df_mg_10sn_72h = pd.read_excel('/content/drive/My Drive/Colab Notebooks/mg_sn/data/pd/mg_10sn_72h_pd.xlsx')

# %%
df_mg_1sn_24h = df_mg_1sn_24h.iloc[1:]
df_mg_5sn_24h = df_mg_5sn_24h.iloc[1:]
df_mg_10sn_24h = df_mg_10sn_24h.iloc[1:]
df_mg_1sn_48h = df_mg_1sn_48h.iloc[1:]
df_mg_5sn_48h = df_mg_5sn_48h.iloc[1:]
df_mg_10sn_48h = df_mg_10sn_48h.iloc[1:]
df_mg_1sn_72h = df_mg_1sn_72h.iloc[1:]
df_mg_5sn_72h = df_mg_5sn_72h.iloc[1:]
df_mg_10sn_72h = df_mg_10sn_72h.iloc[1:]

# %%
convert_dict = {'XY': float, 'XY': float } 
df_mg_1sn_24h = df_mg_1sn_24h.astype(convert_dict) 
df_mg_5sn_24h = df_mg_5sn_24h.astype(convert_dict) 
df_mg_10sn_24h = df_mg_10sn_24h.astype(convert_dict)
df_mg_1sn_48h = df_mg_1sn_48h.astype(convert_dict) 
df_mg_5sn_48h = df_mg_5sn_48h.astype(convert_dict) 
df_mg_10sn_48h = df_mg_10sn_48h.astype(convert_dict)
df_mg_1sn_72h = df_mg_1sn_72h.astype(convert_dict) 
df_mg_5sn_72h = df_mg_5sn_72h.astype(convert_dict) 
df_mg_10sn_72h = df_mg_10sn_72h.astype(convert_dict)

# %%
df_mg_1sn_24h = df_mg_1sn_24h.rename(columns={"ab": "Img"})
df_mg_5sn_24h = df_mg_5sn_24h.rename(columns={"sp": "Img"})
df_mg_10sn_24h = df_mg_10sn_24h.rename(columns={"htsp": "Img"})
df_mg_1sn_48h = df_mg_1sn_48h.rename(columns={"ab": "Img"})
df_mg_5sn_48h = df_mg_5sn_48h.rename(columns={"ab": "Img"})
df_mg_10sn_48h = df_mg_5sn_48h.rename(columns={"ab": "Img"})
df_mg_1sn_72h = df_mg_1sn_72h.rename(columns={"ab": "Img"})
df_mg_5sn_72h = df_mg_5sn_72h.rename(columns={"ab": "Img"})
df_mg_10sn_72h = df_mg_10sn_72h.rename(columns={"ab": "Img"})

# %%
plt.plot(df_mg_1sn_24h["Img"].values,np.log10(df_mg_1sn_24h['XY'].values),'r',label = 'mg_1sn 24hr')
plt.plot(df_mg_1sn_48h["Img"].values,np.log10(df_mg_1sn_48h['XY'].values),'b',label = 'mg_1sn 48hr')
plt.plot(df_mg_1sn_72h["Img"].values,np.log10(df_mg_1sn_72h['XY'].values),'g',label = 'mg_1sn 72hr')
plt.legend()
plt.title('Potentiodynamic Plot')

plt.show()

# %%
plt.plot(df_mg_5sn_24h["Img"].values,np.log10(df_mg_5sn_24h['XY'].values),'r',label = 'mg_5sn 24hr')
plt.plot(df_mg_5sn_48h["Img"].values,np.log10(df_mg_5sn_48h['XY'].values),'b',label = 'mg_5sn 48hr')
plt.plot(df_mg_5sn_72h["Img"].values,np.log10(df_mg_5sn_72h['XY'].values),'g',label = 'mg_5sn 72hr')
plt.legend()
plt.title('Potentiodynamic Plot')

plt.show()

# %%
plt.plot(df_mg_10sn_24h["Img"].values,np.log10(df_mg_10sn_24h['XY'].values),'r',label = 'mg_10sn 24hr')
plt.plot(df_mg_10sn_48h["Img"].values,np.log10(df_mg_10sn_48h['XY'].values),'b',label = 'mg_10sn 48hr')
plt.plot(df_mg_10sn_72h["Img"].values,np.log10(df_mg_10sn_72h['XY'].values),'g',label = 'mg_10sn 72hr')
plt.legend()
plt.title('Potentiodynamic Plot')

plt.show()

# %%
result_df = pd.concat([df_mg_5sn_24h,df_mg_5sn_48h,df_mg_5sn_72h])

# %%
result_df.columns
# Out:
# Index(['XY', 'Img'], dtype='object')

# %%
print_df = result_df.rename(columns={'Img':"V",'XY':'I'})

# %%
result_df['Img'] = result_df['Img'].values.astype('float64')

# %%
x, y = result_df.drop(['XY'], axis=1), np.log10(result_df['XY'].values.astype('float64'))

# %%
result_df.shape
# Out:
# (14400, 2)

# %% [markdown]
# xg boost

# %%
import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.15, random_state=4)
xgb_model = xgb.XGBRegressor(random_state = 1, max_depth = 2)
xgb_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,xgb_model.predict(x_test)))
print(mean_absolute_error(y_test,xgb_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,xgb_model.predict(x_test))))
# Out:
# [06:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.6145463656230465
# 0.29319962098232444
# 0.4253585922221722

# %%
print(xgb_model.get_xgb_params())
# Out:
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 1, 'gamma': 0, 'importance_type': 'gain', 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 2, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'nthread': 1, 'objective': 'reg:linear', 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 1, 'subsample': 1, 'verbosity': 1}

# %%
convert_dict = {'Img': float, 'XY': float } 
df_base = df_mg_1sn_24h.astype(convert_dict) 
df_ht = df_mg_1sn_48h.astype(convert_dict) 
df_sp = df_mg_1sn_72h.astype(convert_dict)

# %%
x_train.columns
# Out:
# Index(['Img'], dtype='object')

# %%
plt.plot(df_mg_5sn_24h['Img'].values,np.log10(df_mg_5sn_24h['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_5sn_24h['Img'].values,xgb_model.predict(df_mg_5sn_24h.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ab.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_5sn_48h['Img'].values,np.log10(df_mg_5sn_48h['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_5sn_48h['Img'].values,xgb_model.predict(df_mg_5sn_48h.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_ht.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_72h['Img'].values,np.log10(df_mg_1sn_72h['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_1sn_72h['Img'].values,xgb_model.predict(df_mg_1sn_72h.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_10sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# svm

# %%
from sklearn import svm
svr_model = svm.SVR(kernel='rbf', C=100, gamma=0.5, epsilon=.1)
svr_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,svr_model.predict(x_test)))
print(mean_absolute_error(y_test,svr_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,svr_model.predict(x_test))))
# Out:
# 0.2028270572382198
# 0.3799857144431792
# 0.6474214496280075

# %%
svr_model.get_params()
# Out:
# {'C': 100,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 0.5,
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
plt.plot(df_mg_1sn['Img'].values,np.log10(df_mg_1sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_1sn['Img'].values,svr_model.predict(df_mg_1sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_svm_1sn.png',dpi = 1200,bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a73ffbb499ca> in <module>
# ----> 1 plt.plot(df_mg_1sn['Img'].values,np.log10(df_mg_1sn['XY'].values),'r',label = 'Experimental')
#       2 plt.plot(df_mg_1sn['Img'].values,svr_model.predict(df_mg_1sn.drop(['XY'],axis=1)),'b',label='Predicted')
#       3 plt.legend()
#       4 #plt.title('Base')
#       5 plt.ylabel('Log(I)    (in A)')
#
# NameError: name 'df_mg_1sn' is not defined

# %%
plt.plot(df_mg_5sn['Img'].values,np.log10(df_mg_5sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_5sn['Img'].values,svr_model.predict(df_mg_5sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_svm_5sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn['Img'].values,np.log10(df_mg_10sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_10sn['Img'].values,svr_model.predict(df_mg_10sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_svm_10sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# decision tree

# %%
from sklearn import tree
dt_model = tree.DecisionTreeRegressor(max_depth=6)
dt_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,dt_model.predict(x_test)))
print(mean_absolute_error(y_test,dt_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,dt_model.predict(x_test))))
# Out:
# 0.379020757463835
# 0.3686661563319998
# 0.5714119921798456

# %%
dt_model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': 6,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
plt.plot(df_mg_1sn['Img'].values,np.log10(df_mg_1sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_1sn['Img'].values,dt_model.predict(df_mg_1sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_dt_1sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_5sn['Img'].values,np.log10(df_mg_5sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_5sn['Img'].values,dt_model.predict(df_mg_5sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_dt_5sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn['Img'].values,np.log10(df_mg_10sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_10sn['Img'].values,dt_model.predict(df_mg_10sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_dt_10sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# poly reg

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

linear_model = LinearRegression()
degree=4
poly_model =make_pipeline(PolynomialFeatures(degree),LinearRegression())

poly_model.fit(x_train,y_train)
#R2
#MAE
#RMSE
print(r2_score(y_test,poly_model.predict(x_test)))
print(mean_absolute_error(y_test,poly_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,poly_model.predict(x_test))))
# Out:
# 0.315451518275909
# 0.3833855452585811
# 0.5999470397676845

# %%
poly_model.get_params()
# Out:
# {'memory': None,
#  'steps': [('polynomialfeatures', PolynomialFeatures(degree=4)),
#   ('linearregression', LinearRegression())],
#  'verbose': False,
#  'polynomialfeatures': PolynomialFeatures(degree=4),
#  'linearregression': LinearRegression(),
#  'polynomialfeatures__degree': 4,
#  'polynomialfeatures__include_bias': True,
#  'polynomialfeatures__interaction_only': False,
#  'polynomialfeatures__order': 'C',
#  'linearregression__copy_X': True,
#  'linearregression__fit_intercept': True,
#  'linearregression__n_jobs': None,
#  'linearregression__normalize': 'deprecated',
#  'linearregression__positive': False}

# %%
plt.plot(df_mg_1sn['Img'].values,np.log10(df_mg_1sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_1sn['Img'].values,poly_model.predict(df_mg_1sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_poly_1sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_5sn['Img'].values,np.log10(df_mg_5sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_5sn['Img'].values,poly_model.predict(df_mg_5sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_poly_5sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_10sn['Img'].values,np.log10(df_mg_10sn['XY'].values),'r',label = 'Experimental')
plt.plot(df_mg_10sn['Img'].values,poly_model.predict(df_mg_10sn.drop(['XY'],axis=1)),'b',label='Predicted')
plt.legend()
#plt.title('Base')
plt.ylabel('Log(I)    (in A)')
plt.xlabel('Voltage    (in V)')
plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_poly_10sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %% [markdown]
# XGBoost Feature Importance

# %%
from xgboost import plot_importance
#reduction in mse
plot_importance(xgb_model)
plt.show()

# %%
hyper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d40cd76c9c4f> in <module>
# ----> 1 hyper
#
# NameError: name 'hyper' is not defined

# %%
pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import optuna

# %%
def xgb_objective(trial):
    train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.15)
    param = {
        'silent': 1,
        'random_state': 0,
        'objective': 'reg:linear',
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-4, 1.0),
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-4, 1.0),
        'n_estimators': trial.suggest_int('n_estimators',10,100),
        'learning_rate': trial.suggest_loguniform('learning_rste', 1e-4, 0.1),
        'max_depth':trial.suggest_int('max_depth',3,6)
    }
    bst = xgb.XGBRegressor(**param)
    bst.fit(train_x,train_y)
    return sqrt(mean_squared_error(test_y,bst.predict(test_x)))

# %%
SEED = 42

np.random.seed(SEED)

xgb_study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(seed=SEED),pruner=optuna.pruners.SuccessiveHalvingPruner())
xgb_study.optimize(xgb_objective, n_trials=100)
# Out:
# [I 2022-09-21 06:26:53,198] A new study created in memory with name: no-name-b5ff1823-615c-4bfd-8b70-0f93ea5c3073
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   if __name__ == '__main__':
# ...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
from typing import Callable
from typing import Optional

import numpy as np

#from optuna._experimental import experimental
from optuna.logging import get_logger
from optuna.study import Study
from optuna.study import StudyDirection
from optuna.trial import FrozenTrial
from optuna.trial import TrialState
from optuna.visualization._utils import _check_plot_args
from optuna.visualization.matplotlib._matplotlib_imports import _imports


if _imports.is_successful():
    from optuna.visualization.matplotlib._matplotlib_imports import Axes
    from optuna.visualization.matplotlib._matplotlib_imports import plt

_logger = get_logger(__name__)

# %%
def optimization_history(
    study: Study,
    *,
    target: Optional[Callable[[FrozenTrial], float]] = None,
    target_name: str = "Objective Value",
) -> "Axes":
    """Plot optimization history of all trials in a study with Matplotlib.
    .. seealso::
        Please refer to :func:`optuna.visualization.plot_optimization_history` for an example.
    Example:
        The following code snippet shows how to plot optimization history.
        .. plot::
            import optuna
            def objective(trial):
                x = trial.suggest_float("x", -100, 100)
                y = trial.suggest_categorical("y", [-1, 0, 1])
                return x ** 2 + y
            sampler = optuna.samplers.TPESampler(seed=10)
            study = optuna.create_study(sampler=sampler)
            study.optimize(objective, n_trials=10)
            optuna.visualization.matplotlib.plot_optimization_history(study)
    Args:
        study:
            A :class:`~optuna.study.Study` object whose trials are plotted for their target values.
        target:
            A function to specify the value to display. If it is :obj:`None` and ``study`` is being
            used for single-objective optimization, the objective values are plotted.
            .. note::
                Specify this argument if ``study`` is being used for multi-objective optimization.
        target_name:
            Target's name to display on the axis label and the legend.
    Returns:
        A :class:`matplotlib.axes.Axes` object.
    Raises:
        :exc:`ValueError`:
            If ``target`` is :obj:`None` and ``study`` is being used for multi-objective
            optimization.
    """

    _imports.check()
    _check_plot_args(study, target, target_name)
    get_optimization_history_plot(study, target, target_name)
    return 0


def get_optimization_history_plot(
    study: Study,
    target: Optional[Callable[[FrozenTrial], float]],
    target_name: str,
) -> "Axes":

    # Set up the graph style.
    fig = plt.figure()
    plt.title("Optimization History Plot")
    plt.xlabel("#Trials")
    plt.ylabel(target_name)
    
    # Prepare data for plotting.
    trials = [t for t in study.trials if t.state == TrialState.COMPLETE]

    if len(trials) == 0:
        _logger.warning("Study instance does not contain trials.")
        return 0

    # Draw a scatter plot and a line plot.
    if target is None:
        if study.direction == StudyDirection.MINIMIZE:
            best_values = np.minimum.accumulate([t.value for t in trials])
        else:
            best_values = np.maximum.accumulate([t.value for t in trials])
        plt.scatter(
            x=[t.number for t in trials],
            y=[t.value for t in trials],
            color='blue',
            alpha=1,
            label=target_name,
        )
        plt.plot(
            [t.number for t in trials],
            best_values,
            marker="o",
            color='red',
            alpha=0.5,
            label="Best Value",
        )

        plt.legend()
    else:
        plt.scatter(
            x=[t.number for t in trials],
            y=[target(t) for t in trials],
            color='red',
            alpha=1,
            label=target_name,
        )
    plt.savefig('pd_opt_his.png',dpi = 1200,bbox_inches='tight')
    plt.show()

# %%
optimization_history(xgb_study)
# Out:
# 0

# %%
xgb_study.trials_dataframe()
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  4.050974 2022-09-21 06:26:53.204169 2022-09-21 06:26:53.266870
# 1        1  4.042499 2022-09-21 06:26:53.269950 2022-09-21 06:26:53.322647
# 2        2  4.003818 2022-09-21 06:26:53.325404 2022-09-21 06:26:53.373729
# 3        3  3.700442 2022-09-21 06:26:53.376149 2022-09-21 06:26:53.412574
# 4        4  3.319245 2022-09-21 06:26:53.418127 2022-09-21 06:26:53.569480
# 5        5  3.857933 2022-09-21 06:26:53.571967 2022-09-21 06:26:53.688687
# 6        6  2.333718 2022-09-21 06:26:53.691878 2022-09-21 06:26:55.779114
# 7        7  1.548569 2022-09-21 06:26:55.781769 2022-09-21 06:26:55.843718
# 8        8  0.821625 2022-09-21 06:26:55.846708 2022-09-21 06:26:56.007767
# 9        9  3.990366 2022-09-21 06:26:56.010066 2022-09-21 06:26:56.046793
# 10      10  0.414038 2022-09-21 06:26:56.049213 2022-09-21 06:26:56.633960
# ...

# %%
bst_params = xgb_study.best_params
bst_params
# Out:
# {'booster': 'dart',
#  'reg_lambda': 0.1996606925811629,
#  'reg_alpha': 0.00013199675266665513,
#  'n_estimators': 59,
#  'learning_rste': 0.08839965149111521,
#  'max_depth': 5}

# %%
final_model = xgb.XGBRegressor(**bst_params)
final_model.fit(x_train,y_train)
# Out:
# [06:28:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(booster='dart', learning_rste=0.08839965149111521, max_depth=5,
#              n_estimators=59, reg_alpha=0.00013199675266665513,
#              reg_lambda=0.1996606925811629)

# %%
print(r2_score(y_test,final_model.predict(x_test)))
print(mean_absolute_error(y_test,final_model.predict(x_test)))
print(sqrt(mean_squared_error(y_test,final_model.predict(x_test))))
# Out:
# 0.5796485589922615
# 0.30104497350864107
# 0.4441967818137361

# %%
final_model.feature_importances_
# Out:
# array([1.], dtype=float32)

# %%
final_model.get_booster().get_score(importance_type='gain')
# Out:
# {'Img': 14.003104106665846}

# %%
gain_unnorm =  np.array([14.003104106665846])

# %%
gain = gain_unnorm/np.sum(gain_unnorm)

# %%
gain
# Out:
# array([1.])

# %%
final_model.importance_type
# Out:
# 'gain'

# %%
columns = ['Voltage', 'T', 'inclination']

# %%
gain = np.array([1,0,0])

# %%
def _label_barh(bars, text_format, **kwargs):
    """
    Attach a text label to each bar displaying its y value
    Note: label always outside. otherwise it's too hard to control as numbers can be very long
    """
    max_x_value = ax.get_xlim()[1]
    distance = max_x_value * 0.0025

    for bar in bars:
        text = text_format.format(bar.get_width())

        text_x = bar.get_width() + distance
        text_y = bar.get_y() + bar.get_height() / 2

        plt.text(text_x, text_y, text, va='center', **kwargs)

def label_bars(bars, text_format, **kwargs):
    """
    Attaches a label on every bar of a regular or horizontal bar chart
    """
    ys = [bar.get_y() for bar in bars]
    y_is_constant = all(y == ys[0] for y in ys)  # -> regular bar chart, since all all bars start on the same y level (0)

    if y_is_constant:
        _label_bar(bars, text_format, **kwargs)
    else:
        _label_barh(bars, text_format, **kwargs)

# %%
horizontal_bars = plt.barh(columns, gain, height= 0.5, align="center")
plt.xlim(0,1.0)
plt.ylabel('Features')
plt.xlabel('Importance')
value_format = "{:.4}"  # displaying values as percentage with one fractional digit
label_bars(horizontal_bars, value_format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-b4cab99a2eaa> in <module>
#       4 plt.xlabel('Importance')
#       5 value_format = "{:.4}"  # displaying values as percentage with one fractional digit
# ----> 6 label_bars(horizontal_bars, value_format)
#
# <ipython-input-57-b94f371cdffe> in label_bars(bars, text_format, **kwargs)
#      25         _label_bar(bars, text_format, **kwargs)
#      26     else:
# ---> 27         _label_barh(bars, text_format, **kwargs)
#
# <ipython-input-57-b94f371cdffe> in _label_barh(bars, text_format, **kwargs)
#       4     Note: label always outside. otherwise it's too hard to control as numbers can be very long
#       5     """
# ----> 6     max_x_value = ax.get_xlim()[1]
#       7     distance = max_x_value * 0.0025
#       8
#
# NameError: name 'ax' is not defined

# %%
plt.plot(df_mg_1sn_24h['Img'].values,np.log10(df_mg_1sn_24h['XY'].values),'r',label = 'Experimental 24h')
plt.plot(df_mg_1sn_24h['Img'].values,final_model.predict(df_mg_1sn_24h.drop(['XY'],axis=1)),'b',label='Predicted 24h')
plt.legend()
#plt.title('Base')

plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_1sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_48h['Img'].values,np.log10(df_mg_1sn_48h['XY'].values),'r',label = 'Experimental 48h')
plt.plot(df_mg_1sn_48h['Img'].values,final_model.predict(df_mg_1sn_48h.drop(['XY'],axis=1)),'b',label='Predicted 48h')
plt.legend()
#plt.title('Base')

plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_5sn.png',dpi = 1200,bbox_inches='tight')
plt.show()

# %%
plt.plot(df_mg_1sn_72h['Img'].values,np.log10(df_mg_1sn_72h['XY'].values),'r',label = 'Experimental 72h')
plt.plot(df_mg_1sn_72h['Img'].values,final_model.predict(df_mg_1sn_72h.drop(['XY'],axis=1)),'b',label='Predicted 72h')
plt.legend()
#plt.title('Base')

plt.savefig('/content/drive/My Drive/Colab Notebooks/mg_sn/plots/pd/pd_xgb_10sn.png',dpi = 1200,bbox_inches='tight')
plt.show()
